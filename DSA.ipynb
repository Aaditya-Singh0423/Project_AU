# %%
import time
time.time()           #unix time
# Out:
# 1757757553.4422023

# %%
import time
start=time.time()
total=0
for i in range(100):
    total+=i
print(total)
stop=time.time()
print("Total time taken",stop-start)
# Out:
# 4950
# Total time taken 0.0

# %% [markdown]
# Time Complexity:--
# * O(1)-->constant time complexity
# * O(log n)-->logarithmic time complexity
# * O(n)-->linear time complexity
# * O(n^2)-->quadratic time complexity
# * O(2^n)-->exponential time complexity

# %% [markdown]
# DSA
#
# 1. Array
# 2. Linked List
# 3. Stack
# 4. Queue
# 5. Tree
# 6. Graph
# 7. Hash Table
# 8. Heap
# 9. Priority Queue
# 10. Set
# 11. Dictionary

# %% [markdown]
# * Big O
# * Big-Omega
# * Little O
# * Theta
# * Little-Omega

# %%
#Bubble sort

def bubble_sort(arr):
    n=len(arr)
    for i in range(n):
        for j in range(0,n-i-1):
            if arr[j]>arr[j+1]:
                arr[j],arr[j+1]=arr[j+1],arr[j]
    return arr

# %%
arr=input("Enter the array").split()
arr=[int(i) for i in arr]
print(bubble_sort(arr))
# Out:
# [2, 10, 12, 12, 15, 24, 32, 52]

# %%
#reverse of a number
num=int(input("Enter a number:\t"))          #This will take input from the user
print("The number before reverse is", num)   #This will print the number before reverse
rev=0                                        #This will store the reversed number
while num>0:                                 #This will run the loop as long as the number is greater than 0
    mod=num%10                               #This will store the last digit of the number
    rev=rev*10+mod                           #This will add the last digit of the number to the reversed number
    num=num//10                              #This will remove the last digit of the number
print(rev)                                   #This will print the reversed number
# Out:
# The number before reverse is 45
# 54

# %%
n=int(input("Enter a number:\t"))
result=" "
while n>0:
    mod=n%10
    result=str(mod)+result
    n=n//10
print(result)
# Out:
# 65

# %%
def fib(n):
    if n==0 or n==1:
        return 1
    fib (n-1)+fib(n-2)
    return fib(n-1)+fib(n-2)

# %%
#Create a code for merge sort
def merge_sort(arr):
    if len(arr)>1:
        mid=len(arr)//2
        left=arr[:mid]
        right=arr[mid:]
        merge_sort(left)
        merge_sort(right)
        i=j=k=0
        while i<len(left) and j<len(right):
            if left[i]<right[j]:
                arr[k]=left[i]
                i+=1
            else:
                arr[k]=right[j]
                j+=1
            k+=1
        while i<len(left):
            arr[k]=left[i]
            i+=1
            k+=1
        while j<len(right):
            arr[k]=right[j]
            j+=1
            k+=1
    return arr
# Out:
# [2, 15, 42, 52, 32, 12, 52, 145, 25, 75]
